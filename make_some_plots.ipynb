# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('train.csv')
#df.head()
#df.info()

df1 = df[['Cover_Type','Elevation', 'Aspect', 'Slope']]
df1.head()
# Out:
#    Cover_Type  Elevation  Aspect  Slope
# 0           5       2596      51      3
# 1           5       2590      56      2
# 2           2       2804     139      9
# 3           2       2785     155     18
# 4           5       2595      45      2

# %%
sns.pairplot(df1)

# %%
sns.violinplot(data = df, x = 'Cover_Type', y = 'Aspect')

# %%
sns.violinplot(data = df, x = 'Cover_Type', y = 'Hillshade_9am')

# %%
sns.violinplot(data = df, x = 'Cover_Type', y = 'Elevation')
